# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/data/dbs/stability_megascale/Processed_K50_dG_datasets/Tsuboyama2023_Dataset2_Dataset3_20230416.csv")
# Out:
# /tmp/ipykernel_282966/803329226.py:1: DtypeWarning: Columns (30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/data/dbs/stability_megascale/Processed_K50_dG_datasets/Tsuboyama2023_Dataset2_Dataset3_20230416.csv")

# %%
import matplotlib.pyplot as plt

# %%
df  =  df[df["ddG_ML"] != "-"]

# %%
df["ddG_ML"].iloc[::100].values.astype(float)
# Out:
# array([ 0.01719763, -0.71131915,  0.04978157, ..., -1.21668887,
#        -0.35202301, -1.3912229 ])

# %%
plt.hist(df["ddG_ML"].iloc[::100].values.astype(float))
plt.show()
